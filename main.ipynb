# %% [markdown]
# # Lab | Text Generation from Shakespeare's Sonnet
#
# This notebook explores the fascinating domain of text generation using a deep learning model trained on Shakespeare's sonnets.
#
# The objective is to create a neural network capable of generating text sequences that mimic the style and language of Shakespeare.
#
# By utilizing a Recurrent Neural Network (RNN) with Long Short-Term Memory (LSTM) layers, this project aims to demonstrate how a model can learn and replicate the complex patterns of early modern English.
#
# The dataset used consists of Shakespeare's sonnets, which are preprocessed and tokenized to serve as input for the model.
#
# Throughout this notebook, you will see the steps taken to prepare the data, build and train the model, and evaluate its performance in generating text.
#
# This lab provides a hands-on approach to understanding the intricacies of natural language processing (NLP) and the potential of machine learning in creative text generation.

# %% [markdown]
# Let's import necessary libraries

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow.keras.utils as ku 
import numpy as np

# %% [markdown]
# Let's get the data!

# %%
import requests
url = 'https://raw.githubusercontent.com/martin-gorner/tensorflow-rnn-shakespeare/master/shakespeare/sonnets.txt'
resp = requests.get(url)
with open('sonnets.txt', 'wb') as f:
    f.write(resp.content)

data = open('sonnets.txt').read()

corpus = data.lower().split("\n")

# %% [markdown]
# Step 1: Initialise a tokenizer and fit it on the corpus variable using .fit_on_texts

# %%
# Your code here :
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# %% [markdown]
# Step 2: Calculate the Vocabulary Size
#
# Let's figure out how many unique words are in your corpus. This will be the size of your vocabulary.
#
# Calculate the length of tokenizer.word_index, add 1 to it and store it in a variable called total_words.

# %%
# Your code here :
total_words = len(tokenizer.word_index) + 1
print(total_words)
# Out:
# 3375

# %% [markdown]
# Create an empty list called input_sequences.
#
# For each sentence in your corpus, convert the text into a sequence of integers using the tokenizer.
# Then, generate n-gram sequences from these tokens.
#
# Store the result in the list input_sequences.

# %%
# Your code here :
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %% [markdown]
# Calculate the length of the longest sequence in input_sequences. Assign the result to a variable called max_sequence_len.
#
# Now pad the sequences using pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre').
# Convert it to a numpy array and assign the result back to our variable called input_sequences.

# %%
# Your code here :
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))
print(input_sequences.shape)
# Out:
# (15484, 11)

# %% [markdown]
# Prepare Predictors and Labels
#
# Split the sequences into two parts:
#
# - Predictors: All elements from input_sequences except the last one.
# - Labels: The last element of each sequence in input_sequences.

# %%
# Your code here :
predictors, labels = input_sequences[:,:-1], input_sequences[:,-1]

# %% [markdown]
# One-Hot Encode the Labels :
#
# Convert the labels (which are integers) into one-hot encoded vectors.
#
# Ensure the length of these vectors matches the total number of unique words in your vocabulary.
#
# Use ku.to_categorical() on labels with num_classes = total_words
#
# Assign the result back to our variable labels.

# %%
# Your code here :
labels = ku.to_categorical(labels, num_classes=total_words)
print(labels.shape)
# Out:
# (15484, 3375)

# %% [markdown]
# # Initialize the Model
#
# Start by creating a Sequential model.
#
# Add Layers to the Model:
#
# Embedding Layer: The first layer is an embedding layer. It converts word indices into dense vectors of fixed size (100 in this case). Set the input length to the maximum sequence length minus one, which corresponds to the number of previous words the model will consider when predicting the next word.
#
# Bidirectional LSTM Layer: Add a Bidirectional LSTM layer with 150 units. This layer allows the model to learn context from both directions (past and future) in the sequence. return_sequences=True
#
# Dropout Layer: Add a dropout layer with a rate of 0.2 to prevent overfitting by randomly setting 20% of the input units to 0 during training.
#
# LSTM Layer: Add a second LSTM layer with 100 units. This layer processes the sequence and passes its output to the next layer.
#
# Dense Layer (Intermediate): Add a dense layer with half the total number of words as units, using ReLU activation. A regularization term (L2) is added to prevent overfitting.
#
# Dense Layer (Output): The final dense layer has as many units as there are words in the vocabulary, with a softmax activation function to output a probability distribution over all words.

# %%
model = Sequential([

    # Your code here :
    Embedding(total_words, 100, input_length=max_sequence_len-1),
    Bidirectional(LSTM(150, return_sequences=True)),
    Dropout(0.2),
    LSTM(100),
    Dense(total_words//2, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dense(total_words, activation='softmax')
])

# %% [markdown]
# # Compile the Model:
#
# Compile the model using categorical crossentropy as the loss function, the Adam optimizer for efficient training, and accuracy as the metric to evaluate during training.

# %%
# Your code here :
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# # Print Model Summary:
#
# Use model.summary() to print a summary of the model, which shows the layers, their output shapes, and the number of parameters.

# %%
# Your code here :
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 10, 100)           337500
#
#  bidirectional (Bidirectiona  (None, 10, 300)          301200
#  l)
#
#  dropout (Dropout)           (None, 10, 300)           0
#
#  lstm_1 (LSTM)               (None, 100)               160400
#
#  dense (Dense)               (None, 1687)              170387
#
#  dense_1 (Dense)             (None, 3375)              5697000
#
# =================================================================
# Total params: 6,666,487
# Trainable params: 6,666,487
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Now train the model for 50 epochs and assign it to a variable called history.
#
# Training the model with 50 epochs should get you around 40% accuracy.
#
# You can train the model for as many epochs as you like depending on the time and computing constraints you are facing. Ideally train it for a larger amount of epochs than 50.
#
# That way you will get better text generation at the end.
#
# However, dont waste your time.

# %%
# Your code here :
history = model.fit(predictors, labels, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 484/484 [==============================] - 12s 11ms/step - loss: 6.9165 - accuracy: 0.0209
# Epoch 2/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.5107 - accuracy: 0.0217
# Epoch 3/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.4168 - accuracy: 0.0240
# Epoch 4/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.2968 - accuracy: 0.0289
# Epoch 5/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.1920 - accuracy: 0.0342
# Epoch 6/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.1019 - accuracy: 0.0398
# Epoch 7/50
# 484/484 [==============================] - 5s 11ms/step - loss: 6.0225 - accuracy: 0.0408
# Epoch 8/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.9385 - accuracy: 0.0432
# Epoch 9/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.8501 - accuracy: 0.0496
# Epoch 10/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.7473 - accuracy: 0.0549
# Epoch 11/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.6356 - accuracy: 0.0601
# Epoch 12/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.5247 - accuracy: 0.0692
# Epoch 13/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.4242 - accuracy: 0.0759
# Epoch 14/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.3151 - accuracy: 0.0847
# Epoch 15/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.2039 - accuracy: 0.0918
# Epoch 16/50
# 484/484 [==============================] - 5s 11ms/step - loss: 5.0987 - accuracy: 0.0971
# Epoch 17/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.9941 - accuracy: 0.1074
# Epoch 18/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.8954 - accuracy: 0.1124
# Epoch 19/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.7994 - accuracy: 0.1222
# Epoch 20/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.7047 - accuracy: 0.1331
# Epoch 21/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.5962 - accuracy: 0.1429
# Epoch 22/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.5056 - accuracy: 0.1538
# Epoch 23/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.4049 - accuracy: 0.1648
# Epoch 24/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.3060 - accuracy: 0.1773
# Epoch 25/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.2155 - accuracy: 0.1875
# Epoch 26/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.1132 - accuracy: 0.2029
# Epoch 27/50
# 484/484 [==============================] - 5s 11ms/step - loss: 4.0271 - accuracy: 0.2157
# Epoch 28/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.9330 - accuracy: 0.2282
# Epoch 29/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.8315 - accuracy: 0.2437
# Epoch 30/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.7406 - accuracy: 0.2628
# Epoch 31/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.6515 - accuracy: 0.2757
# Epoch 32/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.5724 - accuracy: 0.2896
# Epoch 33/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.4920 - accuracy: 0.3075
# Epoch 34/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.3946 - accuracy: 0.3258
# Epoch 35/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.3138 - accuracy: 0.3463
# Epoch 36/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.2234 - accuracy: 0.3655
# Epoch 37/50
# 484/484 [==============================] - 6s 11ms/step - loss: 3.1571 - accuracy: 0.3819
# Epoch 38/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.0813 - accuracy: 0.4025
# Epoch 39/50
# 484/484 [==============================] - 5s 11ms/step - loss: 3.0029 - accuracy: 0.4171
# Epoch 40/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.9376 - accuracy: 0.4318
# Epoch 41/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.8744 - accuracy: 0.4440
# Epoch 42/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.8057 - accuracy: 0.4585
# Epoch 43/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.7491 - accuracy: 0.4748
# Epoch 44/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.6855 - accuracy: 0.4860
# Epoch 45/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.6293 - accuracy: 0.4999
# Epoch 46/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.5622 - accuracy: 0.5162
# Epoch 47/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.5015 - accuracy: 0.5342
# Epoch 48/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.4591 - accuracy: 0.5357
# Epoch 49/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.4032 - accuracy: 0.5514
# Epoch 50/50
# 484/484 [==============================] - 5s 11ms/step - loss: 2.3547 - accuracy: 0.5574

# %% [markdown]
# # Use plt from matplotlib to plot the training accuracy over epochs and the loss over epochs

# %% [markdown]
# First you will have to get the accuracy and loss data over epochs, you can do this by using methods on your model.

# %%
# Your code here :
import matplotlib.pyplot as plt

acc = history.history['accuracy']
loss = history.history['loss']
epochs = range(len(acc))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs, acc)
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs, loss)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Generate text with the model based on a seed text
#
# Now you will create two variables :
#
# - seed_text = 'Write the text you want the model to use as a starting point to generate the next words'
# - next_words = number_of_words_you_want_the_model_to_generate
#
# Please change number_of_words_you_want_the_model_to_generate by an actual integer.

# %%
# Your code here :
seed_text = "Shall I compare thee to a summer's day"
next_words = 20

# %% [markdown]
# Now create a loop that runs based on the next_words variable and generates new text based on your seed_text input string. Print the full text with the generated text at the end.
#
# This time you dont get detailed instructions.
#
# Have fun!

# %%
# Your code here :
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# Shall I compare thee to a summer's day out words repair none live back expire bearing strange still is tend behind alone lies forth thee with thee true

# %% [markdown]
# Experiment with at least 3 different seed_text strings and see what happens!

# %%
# Your code here :
seeds = [
    ("My love is like a rose", 20),
    ("To be or not to be", 20),
    ("The beauty of the world", 20)
]

for seed_text, next_words in seeds:
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    print(seed_text)
    print()
# Out:
# My love is like a rose of all thy 'will ' on my verse doth stand dead pride new wastes days young young days shows none
#
# To be or not to be which i forgot forsworn die behind care on wanting pain twain pride so bad so words lies 'will ' still
#
# The beauty of the world into such youth alone young words weep blushing lie so shine words bright ' remain young young days room told
